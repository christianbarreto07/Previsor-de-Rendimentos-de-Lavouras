# %% [markdown]
# <a href="https://colab.research.google.com/github/chrisbrt/Previsor-de-Rendimentos-de-Lavouras/blob/main/Previsor_de_rendimento_de_lavouras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Imports

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
#Importando bibliotecas importante para a criação do modelo preditivo

# %% [markdown]
# # **Loading** **Data**

# %%
df_rend = pd.read_csv('/content/rendimento_lav.csv') #Carregando e lendo os dados de lavouras.

# %% [markdown]
# # **Data Preparation**

# %%
df_rend #Imprimindo os dados da lavoura
# Out:
#      Chuvas (mm)  Fertilizante  Temperatura  Nitrogênio (N)  Fósforo (P)  \
# 0           1230            80           28              80           24
# 1            480            60           36              70           20
# 2           1250            75           29              78           22
# 3            450            65           35              70           19
# 4           1200            80           27              79           22
# ..           ...           ...          ...             ...          ...
# 94          1250            77           28              78           23
# 95           425            60           39              65           19
# 96          1220            79           28              77           23
# 97           480            65           36              68           21
# 98          1230            80           28              80           24
#
#     Potácio (K)  Rendimento (Q/acre)
# 0            20                   12
# ...

# %%
df_rend.describe()#Descrição dos dados na qual se observa a quantidade, média, desvio padrão, menor valor e maior valor
# Out:
#         Chuvas (mm)  Fertilizante  Temperatura  Nitrogênio (N)  Fósforo (P)  \
# count     99.000000     99.000000    99.000000       99.000000    99.000000
# mean     849.797980     67.808081    32.393939       70.737374    21.131313
# std      400.042676     10.028202     5.426350        6.677079     1.951695
# min      400.000000     50.000000    24.000000       59.000000    18.000000
# 25%      450.000000     60.000000    28.000000       65.000000    19.500000
# 50%     1150.000000     70.000000    29.000000       71.000000    21.000000
# 75%     1237.500000     77.000000    38.000000       77.000000    23.000000
# max     1300.000000     80.000000    40.000000       80.000000    25.000000
#
#        Potácio (K)  Rendimento (Q/acre)
# count    99.000000            99.000000
# mean     18.060606             9.131313
# std       1.817254             1.930668
# min      15.000000             6.000000
# 25%      16.000000             7.000000
# ...

# %%
df_rend.tail()#Imprimindo as 5 ultimas linhas dos dados da lavoura
# Out:
#      Chuvas (mm)  Fertilizante  Temperatura  Nitrogênio (N)  Fósforo (P)  \
# 94          1250            77           28              78           23
# 95           425            60           39              65           19
# 96          1220            79           28              77           23
# 97           480            65           36              68           21
# 98          1230            80           28              80           24
#
#     Potácio (K)  Rendimento (Q/acre)
# 94           20                    9
# 95           17                    7
# 96           21                   11
# 97           16                    7
# 98           20                   12

# %%
df_rend[df_rend['Rendimento (Q/acre)'] == 12.000000]
#Pesquisa das lavouras na qual o rendimento foi máximo. E uma descrição dessas lavouras.
#Obsersado que, chuvas entre 1200-1300, fertilizantes entre 75-80, temperatura entre 26-28, nitrogênio entre 75-80, fósforo entre- 22-24 e potácio entre 19-20,
#geraram um rendimento máximo comparado aos outros rendimentos
# Out:
#      Chuvas (mm)  Fertilizante  Temperatura  Nitrogênio (N)  Fósforo (P)  \
# 0           1230            80           28              80           24
# 8           1200            77           27              78           23
# 10          1280            80           26              80           24
# 16          1300            80           28              80           24
# 19          1200            78           27              78           23
# 27          1250            80           28              80           24
# 38          1250            75           26              75           22
# 76          1300            80           28              80           24
# 98          1230            80           28              80           24
#
#     Potácio (K)  Rendimento (Q/acre)
# 0            20                   12
# 8            20                   12
# 10           20                   12
# 16           20                   12
# 19           19                   12
# ...

# %%
df_rend[df_rend['Rendimento (Q/acre)'] == 6.000000].describe()
#Menor rendimento, poucas chuvas, temperatura acima da media, solo pouco nutrido.
# Out:
#         Chuvas (mm)  Fertilizante  Temperatura  Nitrogênio (N)  Fósforo (P)  \
# count     10.000000     10.000000    10.000000       10.000000    10.000000
# mean     420.000000     56.000000    38.700000       61.000000    18.200000
# std       25.495098      5.676462     0.948683        2.160247     0.421637
# min      400.000000     50.000000    37.000000       59.000000    18.000000
# 25%      400.000000     50.000000    39.000000       60.000000    18.000000
# 50%      410.000000     57.500000    39.000000       60.000000    18.000000
# 75%      428.750000     60.000000    39.000000       60.750000    18.000000
# max      475.000000     65.000000    40.000000       65.000000    19.000000
#
#        Potácio (K)  Rendimento (Q/acre)
# count    10.000000                 10.0
# mean     15.200000                  6.0
# std       0.421637                  0.0
# min      15.000000                  6.0
# 25%      15.000000                  6.0
# ...

# %%
df_rend[df_rend['Rendimento (Q/acre)'] == 6.000000] #Pesquisando nos dados da lavoura as linhas com o menor rendimento.
# Out:
#      Chuvas (mm)  Fertilizante  Temperatura  Nitrogênio (N)  Fósforo (P)  \
# 9            400            50           39              60           18
# 15           400            60           39              60           18
# 20           410            50           37              59           19
# 26           400            60           39              60           18
# 31           475            55           39              61           18
# 37           425            60           39              60           18
# 43           410            60           39              65           18
# 49           450            50           37              60           18
# 51           430            65           39              65           19
# 77           400            50           40              60           18
#
#     Potácio (K)  Rendimento (Q/acre)
# 9            15                    6
# 15           15                    6
# 20           15                    6
# ...

# %% [markdown]
# Divisão dos previsores e classe.

# %%
X_rend = df_rend.iloc[:,0:6].values #Coletar todas as linhas para selecionar os previsores.
X_rend #Mostrar os dados previsores. ND array (Matriz).

# %%
Y_rend = df_rend.iloc[:,6].values #Coletando coluna da classe de rendimentos.
Y_rend #Mostrando a coluna
# Out:
# array([12,  8, 11,  9, 11, 10, 11,  7, 12,  6, 12,  8, 11,  9, 11,  6, 12,
#         7, 11, 12,  6, 11,  7, 10,  9, 10,  6, 12,  7, 10, 11,  6, 11,  7,
#        10,  9, 10,  6, 12,  8, 11,  7, 11,  6, 11,  7, 11,  8, 10,  6, 11,
#         6, 11,  7, 10,  8, 11,  9, 10,  7, 11,  7, 11,  7, 11,  7, 11,  7,
#        10,  9, 10,  8, 11,  7, 10,  8, 12,  6, 10,  8, 10,  8, 10,  9,  9,
#         8, 10,  8, 11,  7, 11,  7,  9,  8,  9,  7, 11,  7, 12])

# %% [markdown]
# Divisão das bases de Treinamento e Teste

# %%
from sklearn.model_selection import train_test_split #Importando função para separar os dados de treinamento e para previsores e classe

# %%
X_rend_treinamento, X_rend_teste, Y_rend_treinamento, Y_rend_teste = train_test_split(X_rend, Y_rend, test_size = 0.25, random_state = 0)
#Criando variaveis dos atributos previsores(X) e classe(Y) para treinamento e teste.

# %%
X_rend_treinamento.shape
# Out:
# (74, 6)

# %%
Y_rend_treinamento.shape
# Out:
# (74,)

# %% [markdown]
# Salvando base de dados

# %%
import pickle
with open('rend_lav.pkl', mode = 'wb') as f:
  pickle.dump([X_rend_treinamento, X_rend_teste, Y_rend_treinamento, Y_rend_teste], f)

# %% [markdown]
# # **Naive Bayes**

# %%
X_rend_treinamento

# %% [markdown]
# Etapa de treinamento do algoritmo

# %%
naive_rend = GaussianNB()
naive_rend.fit(X_rend_treinamento,Y_rend_treinamento)
# Out:
# GaussianNB()

# %%
previsao = naive_rend.predict(X_rend_teste) #Fazendo uma previsão usando os registros de testes que foram separados.

# %%
previsao
# Out:
# array([ 6, 11, 11,  8,  7, 10, 12,  8, 11, 12,  6,  7, 10,  8,  7, 11,  7,
#         8,  7, 11,  6, 11,  8,  7,  8])

# %% [markdown]
# Agora vou imprimir o resultado original e correto dele para verificar se as predições foram corretas ou se a margem de erro foi baixa/alta.

# %%
Y_rend_teste
# Out:
# array([ 6, 10, 11,  8,  8,  9, 12,  7, 10,  9,  7,  7, 10,  9,  7, 11,  7,
#         9,  7, 12,  6, 11,  9,  8,  7])

# %% [markdown]
# Agora comparei as respostas.

# %%
from sklearn.metrics import accuracy_score #Importando a biblioteca e a função para verificar a taxa de acerto do algoritmo referente aos dados.

# %%
accuracy_score(Y_rend_teste, previsao)#Aqui veremos o número que corresponde aos acertos da maquina, se multiplicarmos por 100, obteremos que a taxa de acerto é de 48%.
# Out:
# 0.48
